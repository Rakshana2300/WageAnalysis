# %%
import pandas as pd
df=pd.read_csv("datasets1/Minimum Wage Data.csv",encoding="Latin")
df.to_csv("datasets1/minwage.csv",encoding="utf-8")
df=pd.read_csv("datasets1/minwage.csv")
gb=df.groupby("State")
gb.get_group("Alabama").set_index("Year").tail()
# Out:
#       Unnamed: 0    State Table_Data Footnote  High.Value  Low.Value  \
# Year
# 2013        2475  Alabama        ...      NaN         0.0        0.0
# 2014        2530  Alabama        ...      NaN         0.0        0.0
# 2015        2585  Alabama        ...      NaN         0.0        0.0
# 2016        2640  Alabama        ...      NaN         0.0        0.0
# 2017        2695  Alabama        ...      NaN         0.0        0.0
#
#       CPI.Average  High.2018  Low.2018
# Year
# 2013   232.957083        0.0       0.0
# 2014   236.736167        0.0       0.0
# 2015   237.017000        0.0       0.0
# 2016   240.007167        0.0       0.0
# 2017   245.119583        0.0       0.0

# %%
min_wage=pd.DataFrame()
for name,group in df.groupby("State"):
    if min_wage.empty:
        min_wage=group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        min_wage=min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))
min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.12     3.37      1.12       11.88      7.20        10.08
# 1969      0.0   14.33     3.19      1.07       11.26      6.83         9.56
# 1970      0.0   13.54     3.02      7.09       10.64      6.45        10.32
# 1971      0.0   12.99     2.89      6.80       10.20      6.18         9.89
# 1972      0.0   12.57     2.80      7.19        9.88      5.99        11.08
#
#       Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                  ...
# 1968      9.00                  9.00            8.28  ...        0.0   0.00
# 1969      8.53                  8.53            7.85  ...        0.0   0.00
# 1970      8.06                 10.32            8.38  ...        0.0   0.00
# 1971      7.73                  9.89            8.04  ...        0.0   0.00
# ...

# %%
min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     50.0  50.000000  50.000000  50.000000   50.000000  50.000000
# mean       0.0   9.583800   2.316200   6.781600    8.632800   6.389800
# std        0.0   1.845176   3.474504   1.341223    1.187508   1.521052
# min        0.0   7.380000   0.000000   1.070000    6.420000   3.840000
# 25%        0.0   8.252500   0.000000   6.522500    7.695000   5.072500
# 50%        0.0   8.890000   0.000000   6.920000    8.670000   6.375000
# 75%        0.0  10.492500   3.147500   7.290000    9.307500   7.677500
# max        0.0  15.120000  10.220000   8.680000   11.880000   9.500000
#
#        Connecticut   Delaware  District of Columbia  Federal (FLSA)  ...  \
# count    50.000000  50.000000             50.000000       50.000000  ...
# mean      8.823600   7.498800              8.343200        7.773200  ...
# std       1.023613   1.265436              1.476133        0.887354  ...
# ...

# %%
min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.018638 -0.377934    0.717653 -0.129332
# Arizona         NaN  0.018638  1.000000  0.089395    0.498994  0.742527
# Arkansas        NaN -0.377934  0.089395  1.000000   -0.234367  0.135749
# California      NaN  0.717653  0.498994 -0.234367    1.000000  0.483313
#
#             Connecticut  Delaware  District of Columbia  Federal (FLSA)  ...  \
# Alabama             NaN       NaN                   NaN             NaN  ...
# Alaska         0.680886  0.258997              0.321785        0.637679  ...
# Arizona        0.458163  0.429836              0.590848       -0.049914  ...
# Arkansas       0.047580  0.016125              0.266889        0.117245  ...
# California     0.876215  0.479197              0.596865        0.371966  ...
#
# ...

# %%
df.groupby("State").head()
# Out:
#      Unnamed: 0  Year          State           Table_Data Footnote  \
# 0             0  1968        Alabama                  ...      NaN
# 1             1  1968         Alaska                 2.10      NaN
# 2             2  1968        Arizona  18.72 - 26.40/wk(b)      (b)
# 3             3  1968       Arkansas          1.25/day(b)      (b)
# 4             4  1968     California              1.65(b)      (b)
# ..          ...   ...            ...                  ...      ...
# 270         270  1972       Virginia                  ...      NaN
# 271         271  1972     Washington                 1.60      NaN
# 272         272  1972  West Virginia                 1.20      NaN
# 273         273  1972      Wisconsin             1.45 (b)      (b)
# 274         274  1972        Wyoming                 1.50      NaN
#
#      High.Value  Low.Value  CPI.Average  High.2018  Low.2018
# 0       0.00000    0.00000    34.783333       0.00      0.00
# ...

# %%
issue_df=df[df["Low.2018"]==0]
issue_df["State"].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'Arizona'],
#       dtype=object)

# %%
import numpy as np
min_wage.replace(0,np.NaN).dropna(axis=1).head()
min_wage.plot(legend=False)

# %%
grp_issues=issue_df.groupby("State")
for state,data in grp_issues:
    if data["Low.2018"].sum()!=0.0:
        print("Some data are missing..!!")

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("datasets1/Minimum Wage Data.csv",encoding="Latin")
df.to_csv("datasets1/minwage.csv",encoding="utf-8")
df=pd.read_csv("datasets1/minwage.csv")
min_wage=pd.DataFrame()
for name,group in df.groupby("State"):
    if min_wage.empty:
        min_wage=group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        min_wage=min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))
min_wage_corr=min_wage.replace(0,np.NaN).dropna(axis=1).corr()
min_wage_corr.head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
# ...

# %%
import matplotlib.pyplot as plt
plt.matshow(min_wage_corr)

# %%
labels=[c[:2] for c in min_wage_corr.columns]
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111)
ax.matshow(min_wage_corr,cmap=plt.cm.RdYlGn)
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
plt.show()

# %%
import requests
import pandas as pd
web=requests.get("https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes")
dfs=pd.read_html(web.text)
for df in dfs:
    print(df.head())
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA
#   Territory/Associate Abbreviation Postal Code
# 0      American Samoa          NaN          AS
# 1                Guam         Guam          GU
# 2    Marshall Islands          NaN          MH
# 3          Micronesia          NaN          FM
# 4   Northern Marianas          NaN          MP

# %%
dfs=pd.read_html("https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes")
state_abrev=dfs[0]
state_abrev.head()
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA

# %%
state_abrev[["State/District", "Postal Code"]].to_csv("datasets1/state_abrev.csv",index=False)
state_abrev=pd.read_csv("datasets1/state_abrev.csv",index_col=0)
abrev_dict=state_abrev.to_dict()
abrev_dict=abrev_dict["Postal Code"]
abrev_dict
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
# ...

# %%
labels = [abrev_dict[c] for c in min_wage_corr.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-07929e74c97d> in <module>
# ----> 1 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# <ipython-input-16-07929e74c97d> in <listcomp>(.0)
# ----> 1 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# KeyError: 'Federal (FLSA)'

# %%
abrev_dict["Federal (FLSA)"]="FLSA"

# %%
labels = [abrev_dict[c] for c in min_wage_corr.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-07929e74c97d> in <module>
# ----> 1 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# <ipython-input-18-07929e74c97d> in <listcomp>(.0)
# ----> 1 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# KeyError: 'Guam'

# %%
abrev_dict["Guam"]="GU"
labels = [abrev_dict[c] for c in min_wage_corr.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-de92d4677794> in <module>
#       1 abrev_dict["Guam"]="GU"
# ----> 2 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# <ipython-input-19-de92d4677794> in <listcomp>(.0)
#       1 abrev_dict["Guam"]="GU"
# ----> 2 labels = [abrev_dict[c] for c in min_wage_corr.columns]
#
# KeyError: 'Puerto Rico'

# %%
abrev_dict["Puerto Rico"]="PR"
labels = [abrev_dict[c] for c in min_wage_corr.columns]
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111)
ax.matshow(min_wage_corr,cmap=plt.cm.RdYlGn)
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
plt.show()
